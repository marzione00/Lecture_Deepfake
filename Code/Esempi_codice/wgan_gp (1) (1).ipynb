# %% [markdown]
# # 🤪 WGAN - CelebA Faces

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own Wasserstein GAN on the CelebA faces dataset

# %% [markdown]
# The code has been adapted from the excellent [WGAN-GP tutorial](https://keras.io/examples/generative/wgan_gp/) created by Aakash Kumar Nain, available on the Keras website.

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np

import tensorflow as tf
from tensorflow.keras import (
    layers,
    models,
    callbacks,
    utils,
    metrics,
    optimizers,
)
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#!unzip archive.zip -d archive

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
IMAGE_SIZE = 64
CHANNELS = 3
BATCH_SIZE = 512
NUM_FEATURES = 64
Z_DIM = 128
LEARNING_RATE = 0.0002
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.999
EPOCHS = 200
CRITIC_STEPS = 3
GP_WEIGHT = 10.0
LOAD_MODEL = False
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.9

# %% [markdown]
# ## 1. Prepare the data <a name="prepare"></a>

# %%
# Load the data
train_data = utils.image_dataset_from_directory(
    "archive/t/celebA/",
    labels=None,
    color_mode="rgb",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    interpolation="bilinear",
)
# Out:
# Found 30000 files.

# %%
# Preprocess the data
def preprocess(img):
    """
    Normalize and reshape the images
    """
    img = (tf.cast(img, "float32") - 127.5) / 127.5
    return img


train = train_data.map(lambda x: preprocess(x))

# %%
def display(
    images, n=10, size=(20, 3), cmap="gray_r", as_type="float32", save_to=None
):
    """
    Displays n random images from each one of the supplied arrays.
    """
    if images.max() > 1.0:
        images = images / 255.0
    elif images.min() < 0.0:
        images = (images + 1.0) / 2.0

    plt.figure(figsize=size)
    for i in range(n):
        _ = plt.subplot(1, n, i + 1)
        plt.imshow(images[i].astype(as_type), cmap=cmap)
        plt.axis("off")

    if save_to:
        plt.savefig(save_to)
        print(f"\nSaved to {save_to}")

    plt.show()

# %%
def sample_batch(dataset):
    batch = dataset.take(1).get_single_element()
    if isinstance(batch, tuple):
        batch = batch[0]
    return batch.numpy()

# %%
# Show some faces from the training set
train_sample = sample_batch(train)

# %%
display(train_sample, cmap=None)

# %% [markdown]
# ## 2. Build the WGAN-GP <a name="build"></a>

# %%
critic_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
x = layers.Conv2D(64, kernel_size=4, strides=2, padding="same")(critic_input)
x = layers.LeakyReLU(0.2)(x)
x = layers.Conv2D(128, kernel_size=4, strides=2, padding="same")(x)
x = layers.LeakyReLU()(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(256, kernel_size=4, strides=2, padding="same")(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(512, kernel_size=4, strides=2, padding="same")(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(1, kernel_size=4, strides=1, padding="valid")(x)
critic_output = layers.Flatten()(x)

critic = models.Model(critic_input, critic_output)
critic.summary()
# Out:
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 32, 32, 64)     │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_32 (LeakyReLU)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 16, 16, 128)    │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_33 (LeakyReLU)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 8, 8, 256)      │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_34 (LeakyReLU)      │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 4, 4, 512)      │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_35 (LeakyReLU)      │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 1, 1, 1)        │         8,193 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,764,737 (10.55 MB)
#  Trainable params: 2,764,737 (10.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
generator_input = layers.Input(shape=(Z_DIM,))
x = layers.Reshape((1, 1, Z_DIM))(generator_input)
x = layers.Conv2DTranspose(
    512, kernel_size=4, strides=1, padding="valid", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Conv2DTranspose(
    256, kernel_size=4, strides=2, padding="same", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Conv2DTranspose(
    128, kernel_size=4, strides=2, padding="same", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Conv2DTranspose(
    64, kernel_size=4, strides=2, padding="same", use_bias=False
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
generator_output = layers.Conv2DTranspose(
    CHANNELS, kernel_size=4, strides=2, padding="same", activation="tanh"
)(x)
generator = models.Model(generator_input, generator_output)
generator.summary()
# Out:
# Model: "functional_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_4 (Reshape)             │ (None, 1, 1, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_20             │ (None, 4, 4, 512)      │     1,048,576 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 4, 4, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_36 (LeakyReLU)      │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_21             │ (None, 8, 8, 256)      │     2,097,152 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_37 (LeakyReLU)      │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_22             │ (None, 16, 16, 128)    │       524,288 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_38 (LeakyReLU)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_23             │ (None, 32, 32, 64)     │       131,072 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_39 (LeakyReLU)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_24             │ (None, 64, 64, 3)      │         3,075 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,808,003 (14.53 MB)
#  Trainable params: 3,806,083 (14.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
class WGANGP(models.Model):
    def __init__(self, critic, generator, latent_dim, critic_steps, gp_weight):
        super(WGANGP, self).__init__()
        self.critic = critic
        self.generator = generator
        self.latent_dim = latent_dim
        self.critic_steps = critic_steps
        self.gp_weight = gp_weight

    def compile(self, c_optimizer, g_optimizer):
        super(WGANGP, self).compile()
        self.c_optimizer = c_optimizer
        self.g_optimizer = g_optimizer
        self.c_wass_loss_metric = metrics.Mean(name="c_wass_loss")
        self.c_gp_metric = metrics.Mean(name="c_gp")
        self.c_loss_metric = metrics.Mean(name="c_loss")
        self.g_loss_metric = metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [
            self.c_loss_metric,
            self.c_wass_loss_metric,
            self.c_gp_metric,
            self.g_loss_metric,
        ]

    def gradient_penalty(self, batch_size, real_images, fake_images):
        alpha = tf.random.normal([batch_size, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            pred = self.critic(interpolated, training=True)

        grads = gp_tape.gradient(pred, [interpolated])[0]
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        batch_size = tf.shape(real_images)[0]

        for i in range(self.critic_steps):
            random_latent_vectors = tf.random.normal(
                shape=(batch_size, self.latent_dim)
            )

            with tf.GradientTape() as tape:
                fake_images = self.generator(
                    random_latent_vectors, training=True
                )
                fake_predictions = self.critic(fake_images, training=True)
                real_predictions = self.critic(real_images, training=True)

                c_wass_loss = tf.reduce_mean(fake_predictions) - tf.reduce_mean(
                    real_predictions
                )
                c_gp = self.gradient_penalty(
                    batch_size, real_images, fake_images
                )
                c_loss = c_wass_loss + c_gp * self.gp_weight

            c_gradient = tape.gradient(c_loss, self.critic.trainable_variables)
            self.c_optimizer.apply_gradients(
                zip(c_gradient, self.critic.trainable_variables)
            )

        random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim)
        )
        with tf.GradientTape() as tape:
            fake_images = self.generator(random_latent_vectors, training=True)
            fake_predictions = self.critic(fake_images, training=True)
            g_loss = -tf.reduce_mean(fake_predictions)

        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )

        self.c_loss_metric.update_state(c_loss)
        self.c_wass_loss_metric.update_state(c_wass_loss)
        self.c_gp_metric.update_state(c_gp)
        self.g_loss_metric.update_state(g_loss)

        return {m.name: m.result() for m in self.metrics}

# %%
# Create a GAN
wgangp = WGANGP(
    critic=critic,
    generator=generator,
    latent_dim=Z_DIM,
    critic_steps=CRITIC_STEPS,
    gp_weight=GP_WEIGHT,
)

# %%
if LOAD_MODEL:
    wgangp.load_weights("archive/t/celebA/checkpoint/checkpoint.ckpt")

# %% [markdown]
# ## 3. Train the GAN <a name="train"></a>

# %%
# Compile the GAN
wgangp.compile(
    c_optimizer=optimizers.Adam(
        learning_rate=LEARNING_RATE, beta_1=ADAM_BETA_1, beta_2=ADAM_BETA_2
    ),
    g_optimizer=optimizers.Adam(
        learning_rate=LEARNING_RATE, beta_1=ADAM_BETA_1, beta_2=ADAM_BETA_2
    ),
)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="archive/t/celebA/checkpoint/checkpoint.ckpt",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="archive/t/celebA/logs")


class ImageGenerator(callbacks.Callback):
    def __init__(self, num_img, latent_dim):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(
            shape=(self.num_img, self.latent_dim)
        )
        generated_images = self.model.generator(random_latent_vectors)
        generated_images = generated_images * 127.5 + 127.5
        generated_images = generated_images.numpy()
        display(
            generated_images,
            save_to="archive/t/celebA/output/generated_img_%03d.png" % (epoch),
            cmap=None,
        )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 2
#       1 # Create a model save checkpoint
# ----> 2 model_checkpoint_callback = callbacks.ModelCheckpoint(
#       3     filepath="archive/t/celebA/checkpoint/checkpoint.ckpt",
#       4     save_weights_only=True,
#       5     save_freq="epoch",
#       6     verbose=0,
#       7 )
#       9 tensorboard_callback = callbacks.TensorBoard(log_dir="archive/t/celebA/logs")
#      12 class ImageGenerator(callbacks.Callback):
#
# File /opt/conda/lib/python3.11/site-packages/keras/src/callbacks/model_checkpoint.py:183, in ModelCheckpoint.__init__(self, filepath, monitor, verbose, save_best_only, save_weights_only, mode, save_freq, initial_value_threshold)
#     181 if save_weights_only:
#     182     if not self.filepath.endswith(".weights.h5"):
# --> 183         raise ValueError(
#     184             "When using `save_weights_only=True` in `ModelCheckpoint`"
#     185             ", the filepath provided must end in `.weights.h5` "
#     186             "(Keras weights format). Received: "
#     187             f"filepath={self.filepath}"
#     188         )
#     189 else:
#     190     if not self.filepath.endswith(".keras"):
#
# ValueError: When using `save_weights_only=True` in `ModelCheckpoint`, the filepath provided must end in `.weights.h5` (Keras weights format). Received: filepath=archive/t/celebA/checkpoint/checkpoint.ckpt

# %%
wgangp.fit(
    train,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/200
# 2024-05-19 12:39:48.504499: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] remapper failed: INVALID_ARGUMENT: Mutation::Apply error: fanout 'StatefulPartitionedCall/gradient_tape/functional_17_3/leaky_re_lu_32_1/LeakyRelu/LeakyReluGrad' exist for missing node 'StatefulPartitionedCall/functional_17_3/conv2d_20_1/add'.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - c_gp: 2.7902 - c_loss: -58.9639 - c_wass_loss: -86.8660 - g_loss: 6.9798
# Epoch 2/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - c_gp: 0.4048 - c_loss: -17.4854 - c_wass_loss: -21.5329 - g_loss: -1.4576
# Epoch 3/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - c_gp: 0.2280 - c_loss: -12.9970 - c_wass_loss: -15.2774 - g_loss: -6.3376
# Epoch 4/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - c_gp: 0.2025 - c_loss: -12.5928 - c_wass_loss: -14.6174 - g_loss: -26.8174
# Epoch 5/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - c_gp: 0.2095 - c_loss: -12.2378 - c_wass_loss: -14.3329 - g_loss: -62.3245
# Epoch 6/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 170s 3s/step - c_gp: 0.1723 - c_loss: -10.7666 - c_wass_loss: -12.4901 - g_loss: -55.4996
# Epoch 7/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - c_gp: 0.1521 - c_loss: -9.8831 - c_wass_loss: -11.4045 - g_loss: -46.4335
# Epoch 8/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - c_gp: 0.1411 - c_loss: -9.4157 - c_wass_loss: -10.8269 - g_loss: -35.9440
# Epoch 9/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 192s 3s/step - c_gp: 0.1384 - c_loss: -9.1298 - c_wass_loss: -10.5138 - g_loss: -36.5271
# Epoch 10/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - c_gp: 0.1193 - c_loss: -8.2841 - c_wass_loss: -9.4775 - g_loss: -27.8381
# Epoch 11/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - c_gp: 0.1074 - c_loss: -7.9949 - c_wass_loss: -9.0694 - g_loss: -23.1987
# Epoch 12/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - c_gp: 0.1015 - c_loss: -7.3503 - c_wass_loss: -8.3649 - g_loss: -26.3612
# Epoch 13/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - c_gp: 0.0920 - c_loss: -6.9700 - c_wass_loss: -7.8896 - g_loss: -21.6320
# Epoch 14/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - c_gp: 0.0814 - c_loss: -6.6135 - c_wass_loss: -7.4273 - g_loss: -21.3421
# Epoch 15/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - c_gp: 0.0751 - c_loss: -6.4176 - c_wass_loss: -7.1688 - g_loss: -26.0426
# Epoch 16/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - c_gp: 0.0787 - c_loss: -6.2316 - c_wass_loss: -7.0189 - g_loss: -19.0611
# Epoch 17/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - c_gp: 0.0745 - c_loss: -6.1352 - c_wass_loss: -6.8799 - g_loss: -19.0732
# Epoch 18/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0758 - c_loss: -6.2630 - c_wass_loss: -7.0213 - g_loss: -15.6349
# Epoch 19/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0766 - c_loss: -6.2002 - c_wass_loss: -6.9659 - g_loss: -9.2275
# Epoch 20/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0713 - c_loss: -6.0530 - c_wass_loss: -6.7659 - g_loss: -11.7032
# Epoch 21/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0691 - c_loss: -5.8260 - c_wass_loss: -6.5174 - g_loss: -7.6592
# Epoch 22/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0676 - c_loss: -5.7211 - c_wass_loss: -6.3968 - g_loss: -9.5681
# Epoch 23/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - c_gp: 0.0635 - c_loss: -5.4463 - c_wass_loss: -6.0815 - g_loss: -11.4376
# Epoch 24/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0643 - c_loss: -5.5395 - c_wass_loss: -6.1825 - g_loss: -8.1859
# Epoch 25/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - c_gp: 0.0640 - c_loss: -5.5716 - c_wass_loss: -6.2119 - g_loss: -14.4793
# Epoch 26/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0591 - c_loss: -5.3109 - c_wass_loss: -5.9023 - g_loss: -8.1214
# Epoch 27/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0622 - c_loss: -5.2364 - c_wass_loss: -5.8581 - g_loss: -6.2965
# Epoch 28/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0570 - c_loss: -5.2033 - c_wass_loss: -5.7733 - g_loss: -7.6892
# Epoch 29/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0550 - c_loss: -5.0789 - c_wass_loss: -5.6288 - g_loss: -1.9051
# Epoch 30/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0511 - c_loss: -4.8889 - c_wass_loss: -5.4004 - g_loss: 1.4720
# Epoch 31/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0518 - c_loss: -4.8536 - c_wass_loss: -5.3717 - g_loss: -4.2908
# Epoch 32/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - c_gp: 0.0533 - c_loss: -4.8629 - c_wass_loss: -5.3961 - g_loss: -4.2426
# Epoch 33/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0491 - c_loss: -4.5985 - c_wass_loss: -5.0892 - g_loss: -2.1672
# Epoch 34/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0486 - c_loss: -4.6642 - c_wass_loss: -5.1504 - g_loss: -1.7738
# Epoch 35/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0479 - c_loss: -4.6544 - c_wass_loss: -5.1338 - g_loss: 1.0252
# Epoch 36/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0486 - c_loss: -4.5452 - c_wass_loss: -5.0312 - g_loss: -1.3303
# Epoch 37/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0479 - c_loss: -4.4223 - c_wass_loss: -4.9010 - g_loss: -0.0575
# Epoch 38/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0453 - c_loss: -4.4472 - c_wass_loss: -4.8997 - g_loss: -3.4101
# Epoch 39/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0424 - c_loss: -4.3703 - c_wass_loss: -4.7942 - g_loss: -0.1688
# Epoch 40/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0447 - c_loss: -4.4948 - c_wass_loss: -4.9414 - g_loss: -2.2258
# Epoch 41/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0424 - c_loss: -4.3091 - c_wass_loss: -4.7330 - g_loss: 0.3058
# Epoch 42/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0428 - c_loss: -4.3604 - c_wass_loss: -4.7888 - g_loss: -1.1964
# Epoch 43/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0390 - c_loss: -4.3317 - c_wass_loss: -4.7222 - g_loss: -0.4937
# Epoch 44/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - c_gp: 0.0397 - c_loss: -4.1130 - c_wass_loss: -4.5096 - g_loss: -2.1209
# Epoch 45/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0405 - c_loss: -4.1646 - c_wass_loss: -4.5697 - g_loss: -6.1563
# Epoch 46/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0373 - c_loss: -4.1359 - c_wass_loss: -4.5086 - g_loss: 1.9481
# Epoch 47/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0374 - c_loss: -3.9635 - c_wass_loss: -4.3375 - g_loss: -0.4713
# Epoch 48/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0407 - c_loss: -4.0295 - c_wass_loss: -4.4370 - g_loss: -0.0752
# Epoch 49/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - c_gp: 0.0402 - c_loss: -3.9050 - c_wass_loss: -4.3073 - g_loss: -1.3661
# Epoch 50/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0410 - c_loss: -4.1213 - c_wass_loss: -4.5317 - g_loss: 3.2812
# Epoch 51/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0377 - c_loss: -3.8702 - c_wass_loss: -4.2474 - g_loss: 1.1395
# Epoch 52/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0367 - c_loss: -3.7548 - c_wass_loss: -4.1217 - g_loss: 7.5600
# Epoch 53/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - c_gp: 0.0352 - c_loss: -3.8885 - c_wass_loss: -4.2406 - g_loss: -0.2847
# Epoch 54/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0326 - c_loss: -3.7466 - c_wass_loss: -4.0725 - g_loss: 0.1704
# Epoch 55/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - c_gp: 0.0358 - c_loss: -3.8197 - c_wass_loss: -4.1782 - g_loss: 4.1545
# Epoch 56/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0320 - c_loss: -3.6563 - c_wass_loss: -3.9762 - g_loss: -1.2658
# Epoch 57/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0329 - c_loss: -3.5498 - c_wass_loss: -3.8787 - g_loss: -0.7559
# Epoch 58/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - c_gp: 0.0312 - c_loss: -3.5896 - c_wass_loss: -3.9021 - g_loss: 1.9704
# Epoch 59/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0331 - c_loss: -3.5211 - c_wass_loss: -3.8522 - g_loss: 2.1830
# Epoch 60/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0329 - c_loss: -3.5391 - c_wass_loss: -3.8686 - g_loss: 7.5213
# Epoch 61/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - c_gp: 0.0334 - c_loss: -3.3737 - c_wass_loss: -3.7074 - g_loss: 0.3566
# Epoch 62/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0292 - c_loss: -3.4728 - c_wass_loss: -3.7646 - g_loss: 2.8583
# Epoch 63/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0326 - c_loss: -3.4634 - c_wass_loss: -3.7894 - g_loss: 1.2188
# Epoch 64/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - c_gp: 0.0332 - c_loss: -3.5350 - c_wass_loss: -3.8668 - g_loss: 1.5324
# Epoch 65/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0297 - c_loss: -3.3062 - c_wass_loss: -3.6036 - g_loss: 5.4174
# Epoch 66/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0281 - c_loss: -3.2485 - c_wass_loss: -3.5298 - g_loss: 1.4540
# Epoch 67/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0317 - c_loss: -3.4588 - c_wass_loss: -3.7758 - g_loss: 3.1082
# Epoch 68/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0274 - c_loss: -3.2314 - c_wass_loss: -3.5054 - g_loss: 4.1685
# Epoch 69/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0286 - c_loss: -3.3230 - c_wass_loss: -3.6093 - g_loss: 1.2721
# Epoch 70/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - c_gp: 0.0263 - c_loss: -3.0996 - c_wass_loss: -3.3623 - g_loss: 5.8511
# Epoch 71/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0300 - c_loss: -3.3874 - c_wass_loss: -3.6872 - g_loss: 8.8677
# Epoch 72/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0256 - c_loss: -3.2397 - c_wass_loss: -3.4953 - g_loss: 2.6573
# Epoch 73/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0294 - c_loss: -3.1821 - c_wass_loss: -3.4758 - g_loss: 4.8520
# Epoch 74/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0258 - c_loss: -2.9932 - c_wass_loss: -3.2508 - g_loss: 3.4723
# Epoch 75/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0278 - c_loss: -3.3797 - c_wass_loss: -3.6577 - g_loss: 5.3415
# Epoch 76/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0290 - c_loss: -3.1694 - c_wass_loss: -3.4594 - g_loss: 1.8182
# Epoch 77/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0260 - c_loss: -3.2691 - c_wass_loss: -3.5294 - g_loss: 3.1849
# Epoch 78/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0257 - c_loss: -2.9170 - c_wass_loss: -3.1740 - g_loss: 2.7727
# Epoch 79/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0270 - c_loss: -2.9506 - c_wass_loss: -3.2209 - g_loss: 7.1988
# Epoch 80/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0276 - c_loss: -3.1835 - c_wass_loss: -3.4594 - g_loss: 3.8359
# Epoch 81/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0219 - c_loss: -2.8939 - c_wass_loss: -3.1124 - g_loss: 1.5518
# Epoch 82/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0214 - c_loss: -2.8033 - c_wass_loss: -3.0172 - g_loss: 4.9287
# Epoch 83/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0234 - c_loss: -2.9416 - c_wass_loss: -3.1761 - g_loss: 4.6804
# Epoch 84/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0233 - c_loss: -2.9876 - c_wass_loss: -3.2203 - g_loss: 6.6889
# Epoch 85/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0250 - c_loss: -2.8951 - c_wass_loss: -3.1448 - g_loss: 7.5507
# Epoch 86/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0215 - c_loss: -2.9411 - c_wass_loss: -3.1561 - g_loss: 1.4524
# Epoch 87/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0246 - c_loss: -2.9979 - c_wass_loss: -3.2434 - g_loss: 7.2440
# Epoch 88/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0227 - c_loss: -2.9170 - c_wass_loss: -3.1440 - g_loss: 4.8218
# Epoch 89/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0220 - c_loss: -2.7853 - c_wass_loss: -3.0058 - g_loss: 4.9143
# Epoch 90/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0236 - c_loss: -2.8006 - c_wass_loss: -3.0364 - g_loss: 2.9505
# Epoch 91/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0205 - c_loss: -2.7543 - c_wass_loss: -2.9594 - g_loss: 3.8824
# Epoch 92/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0233 - c_loss: -2.8365 - c_wass_loss: -3.0694 - g_loss: 2.8829
# Epoch 93/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0215 - c_loss: -2.7765 - c_wass_loss: -2.9910 - g_loss: 1.7221
# Epoch 94/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0211 - c_loss: -2.6369 - c_wass_loss: -2.8481 - g_loss: 3.7580
# Epoch 95/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0207 - c_loss: -2.7236 - c_wass_loss: -2.9307 - g_loss: 2.7264
# Epoch 96/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0201 - c_loss: -2.6098 - c_wass_loss: -2.8105 - g_loss: 3.5508
# Epoch 97/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0230 - c_loss: -2.8031 - c_wass_loss: -3.0334 - g_loss: 5.8471
# Epoch 98/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0208 - c_loss: -2.6918 - c_wass_loss: -2.9001 - g_loss: 2.7684
# Epoch 99/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0228 - c_loss: -2.7285 - c_wass_loss: -2.9568 - g_loss: 7.2868
# Epoch 100/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0206 - c_loss: -2.5947 - c_wass_loss: -2.8005 - g_loss: 5.9154
# Epoch 101/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0185 - c_loss: -2.5739 - c_wass_loss: -2.7592 - g_loss: 6.4773
# Epoch 102/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0215 - c_loss: -2.6068 - c_wass_loss: -2.8214 - g_loss: 4.9100
# Epoch 103/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0228 - c_loss: -2.6880 - c_wass_loss: -2.9164 - g_loss: 7.0461
# Epoch 104/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0197 - c_loss: -2.6985 - c_wass_loss: -2.8955 - g_loss: 2.7652
# Epoch 105/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0201 - c_loss: -2.6162 - c_wass_loss: -2.8172 - g_loss: 0.9768
# Epoch 106/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0183 - c_loss: -2.5372 - c_wass_loss: -2.7203 - g_loss: 6.6596
# Epoch 107/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0205 - c_loss: -2.4302 - c_wass_loss: -2.6356 - g_loss: 5.6452
# Epoch 108/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0185 - c_loss: -2.3662 - c_wass_loss: -2.5508 - g_loss: 8.6102
# Epoch 109/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0208 - c_loss: -2.5220 - c_wass_loss: -2.7300 - g_loss: 5.2484
# Epoch 110/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0191 - c_loss: -2.5886 - c_wass_loss: -2.7797 - g_loss: 2.1406
# Epoch 111/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0181 - c_loss: -2.5199 - c_wass_loss: -2.7006 - g_loss: 1.7197
# Epoch 112/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0207 - c_loss: -2.5759 - c_wass_loss: -2.7827 - g_loss: 4.6124
# Epoch 113/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0168 - c_loss: -2.3666 - c_wass_loss: -2.5349 - g_loss: 5.6460
# Epoch 114/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0194 - c_loss: -2.4780 - c_wass_loss: -2.6719 - g_loss: 6.9883
# Epoch 115/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0178 - c_loss: -2.5398 - c_wass_loss: -2.7180 - g_loss: 6.0382
# Epoch 116/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0171 - c_loss: -2.2461 - c_wass_loss: -2.4176 - g_loss: 9.9924
# Epoch 117/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0173 - c_loss: -2.3987 - c_wass_loss: -2.5714 - g_loss: 1.9066
# Epoch 118/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0217 - c_loss: -2.3957 - c_wass_loss: -2.6126 - g_loss: 9.8870
# Epoch 119/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0170 - c_loss: -2.4202 - c_wass_loss: -2.5904 - g_loss: 8.6294
# Epoch 120/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0203 - c_loss: -2.1795 - c_wass_loss: -2.3822 - g_loss: 9.6053
# Epoch 121/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0166 - c_loss: -2.3417 - c_wass_loss: -2.5078 - g_loss: 6.9832
# Epoch 122/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - c_gp: 0.0162 - c_loss: -1.9879 - c_wass_loss: -2.1502 - g_loss: 0.1011
# Epoch 123/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0177 - c_loss: -2.1114 - c_wass_loss: -2.2888 - g_loss: 4.7805
# Epoch 124/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0146 - c_loss: -2.2670 - c_wass_loss: -2.4133 - g_loss: 9.6830
# Epoch 125/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0177 - c_loss: -2.3499 - c_wass_loss: -2.5273 - g_loss: 8.0872
# Epoch 126/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0185 - c_loss: -1.9612 - c_wass_loss: -2.1457 - g_loss: -1.6388
# Epoch 127/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0183 - c_loss: -2.2166 - c_wass_loss: -2.3998 - g_loss: 10.5345
# Epoch 128/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0160 - c_loss: -1.7799 - c_wass_loss: -1.9400 - g_loss: -22.7859
# Epoch 129/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0162 - c_loss: -1.5653 - c_wass_loss: -1.7274 - g_loss: 21.2348
# Epoch 130/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0193 - c_loss: -1.6012 - c_wass_loss: -1.7939 - g_loss: 45.8985
# Epoch 131/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0140 - c_loss: -1.4710 - c_wass_loss: -1.6108 - g_loss: 9.3488
# Epoch 132/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0165 - c_loss: -1.5060 - c_wass_loss: -1.6714 - g_loss: -48.1758
# Epoch 133/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0167 - c_loss: -1.0393 - c_wass_loss: -1.2067 - g_loss: 65.4955
# Epoch 134/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0164 - c_loss: -1.2138 - c_wass_loss: -1.3782 - g_loss: 13.3554
# Epoch 135/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0190 - c_loss: -1.0970 - c_wass_loss: -1.2869 - g_loss: 18.9336
# Epoch 136/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0147 - c_loss: -1.3032 - c_wass_loss: -1.4501 - g_loss: 24.1911
# Epoch 137/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0120 - c_loss: -1.2295 - c_wass_loss: -1.3493 - g_loss: -104.6906
# Epoch 138/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0135 - c_loss: -0.6683 - c_wass_loss: -0.8032 - g_loss: -92.5418
# Epoch 139/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0211 - c_loss: -1.7008 - c_wass_loss: -1.9118 - g_loss: 114.7406
# Epoch 140/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0149 - c_loss: -0.4459 - c_wass_loss: -0.5948 - g_loss: 60.8692
# Epoch 141/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - c_gp: 0.0114 - c_loss: -0.8503 - c_wass_loss: -0.9647 - g_loss: -100.3639
# Epoch 142/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0147 - c_loss: -1.7199 - c_wass_loss: -1.8672 - g_loss: -75.7616
# Epoch 143/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0160 - c_loss: -1.5767 - c_wass_loss: -1.7362 - g_loss: 59.9225
# Epoch 144/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0215 - c_loss: -1.6824 - c_wass_loss: -1.8969 - g_loss: 138.2168
# Epoch 145/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0147 - c_loss: -1.2892 - c_wass_loss: -1.4366 - g_loss: 27.6635
# Epoch 146/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0121 - c_loss: 0.2955 - c_wass_loss: 0.1740 - g_loss: -139.5730
# Epoch 147/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0126 - c_loss: -1.4200 - c_wass_loss: -1.5460 - g_loss: -91.3826
# Epoch 148/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0202 - c_loss: -0.9835 - c_wass_loss: -1.1851 - g_loss: -122.7353
# Epoch 149/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0151 - c_loss: -1.4482 - c_wass_loss: -1.5994 - g_loss: -76.0403
# Epoch 150/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0207 - c_loss: -2.4899 - c_wass_loss: -2.6967 - g_loss: -95.5838
# Epoch 151/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0117 - c_loss: -1.7866 - c_wass_loss: -1.9033 - g_loss: -171.9409
# Epoch 152/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0140 - c_loss: -1.3904 - c_wass_loss: -1.5306 - g_loss: 24.9098
# Epoch 153/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - c_gp: 0.0120 - c_loss: -1.3313 - c_wass_loss: -1.4517 - g_loss: 103.8747
# Epoch 154/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0147 - c_loss: -1.4252 - c_wass_loss: -1.5721 - g_loss: 163.9064
# Epoch 155/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0129 - c_loss: -1.4717 - c_wass_loss: -1.6003 - g_loss: -99.0259
# Epoch 156/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - c_gp: 0.0145 - c_loss: -2.2012 - c_wass_loss: -2.3466 - g_loss: -175.8884
# Epoch 157/200
# 22/59 ━━━━━━━━━━━━━━━━━━━━ 1:45 3s/step - c_gp: 0.0157 - c_loss: -0.8449 - c_wass_loss: -1.0021 - g_loss: 74.8707

# %%
# Save the final models
generator.save("./models/generator100.keras")
critic.save("./models/critic100.keras")

# %% [markdown]
# ## Generate images

# %%
z_sample = np.random.normal(size=(10, Z_DIM))
imgs = wgangp.generator.predict(z_sample)
display(imgs, cmap=None)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
z_sample = np.random.normal(size=(10, Z_DIM))
imgs = wgangp.generator.predict(z_sample)
display(imgs, cmap=None)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
